# %% [markdown]
# ## Please do not run this file. This was used only to select the relevant columns from the large dataset.

# %%
# Import pandas, numpy, and matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import date

# seaborn is a data visualization library built on matplotlib
import seaborn as sns

# set the plotting style
sns.set_style('whitegrid')
# Out:
# python(65345) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.

# %%
school_staff=pd.read_csv('../data/data2.csv',encoding="unicode_escape")
pd.set_option('display.max_columns', None)  
school_staff.head()
# Out:
#   SCHOOL_YEAR  FIPST STATENAME  ST                          SCH_NAME  \
# 0   2016-2017      1   ALABAMA  AL  Sequoyah Sch - Chalkville Campus
# 1   2016-2017      1   ALABAMA  AL                             Camps
# 2   2016-2017      1   ALABAMA  AL                           Det Ctr
# 3   2016-2017      1   ALABAMA  AL     Wallace Sch - Mt Meigs Campus
# 4   2016-2017      1   ALABAMA  AL         McNeel Sch - Vacca Campus
#
#    STATE_AGENCY_NO  UNION ST_LEAID   LEAID     ST_SCHID      NCESSCH   SCHID  \
# 0                1    NaN   AL-210  100002  AL-210-0020  10000200277  100277
# 1                1    NaN   AL-210  100002  AL-210-0050  10000201667  101667
# 2                1    NaN   AL-210  100002  AL-210-0060  10000201670  101670
# 3                1    NaN   AL-210  100002  AL-210-0030  10000201705  101705
# 4                1    NaN   AL-210  100002  AL-210-0040  10000201706  101706
#
#    TEACHERS       TOTAL_INDICATOR  DMS_FLAG
# ...

# %%
school_staff=school_staff[["NCESSCH","TEACHERS"]]

# %%
school_staff.to_csv(
    '../data/staff.csv',
    encoding='utf-8-sig',
    index=False
)

# %%
school_members=pd.read_csv('../data/data3.csv',encoding="unicode_escape")
pd.set_option('display.max_columns', None)  
school_members.head()
# Out:
#   SCHOOL_YEAR  FIPST STATENAME  ST                          SCH_NAME  \
# 0   2016-2017      1   ALABAMA  AL  Sequoyah Sch - Chalkville Campus
# 1   2016-2017      1   ALABAMA  AL  Sequoyah Sch - Chalkville Campus
# 2   2016-2017      1   ALABAMA  AL  Sequoyah Sch - Chalkville Campus
# 3   2016-2017      1   ALABAMA  AL  Sequoyah Sch - Chalkville Campus
# 4   2016-2017      1   ALABAMA  AL  Sequoyah Sch - Chalkville Campus
#
#    STATE_AGENCY_NO  UNION ST_LEAID   LEAID     ST_SCHID      NCESSCH   SCHID  \
# 0                1    NaN   AL-210  100002  AL-210-0020  10000200277  100277
# 1                1    NaN   AL-210  100002  AL-210-0020  10000200277  100277
# 2                1    NaN   AL-210  100002  AL-210-0020  10000200277  100277
# 3                1    NaN   AL-210  100002  AL-210-0020  10000200277  100277
# 4                1    NaN   AL-210  100002  AL-210-0020  10000200277  100277
#
#       GRADE                    RACE_ETHNICITY     SEX  STUDENT_COUNT  \
# ...

# %%
school_members = school_members[["NCESSCH","STUDENT_COUNT","GRADE"]]

# %%
school_members.to_csv(
    '../data/student.csv',
    encoding='utf-8-sig',
    index=False
)
